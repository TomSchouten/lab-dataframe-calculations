# %% [markdown]
# # Challenge 1
#
# In this challenge you will be working on **Pokemon**. You will answer a series of questions in order to practice dataframe calculation, aggregation, and transformation.
#
# ![Pokemon](../images/pokemon.jpg)
#
# Follow the instructions below and enter your code.
#
# #### Import all required libraries.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #### Import data set.
#
# Read the dataset `pokemon.csv` into a dataframe called `pokemon`.
#
# *Data set attributed to [Alberto Barradas](https://www.kaggle.com/abcsds/pokemon/)*

# %%
pokemon = pd.read_csv("pokemon.csv")

# %% [markdown]
# #### Print first 10 rows of `pokemon`.

# %%
pokemon.head(10)
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                    Ivysaur  Grass  Poison    405  60      62       63
# 2  3                   Venusaur  Grass  Poison    525  80      82       83
# 3  3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4                 Charmander   Fire     NaN    309  39      52       43
# 5  5                 Charmeleon   Fire     NaN    405  58      64       58
# 6  6                  Charizard   Fire  Flying    534  78      84       78
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8  6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9  7                   Squirtle  Water     NaN    314  44      48       65
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False
# 5       80       65     80           1      False
# 6      109       85    100           1      False
# 7      130       85    100           1      False
# 8      159      115    100           1      False
# 9       50       64     43           1      False

# %% [markdown]
# When you look at a data set, you often wonder what each column means. Some open-source data sets provide descriptions of the data set. In many cases, data descriptions are extremely useful for data analysts to perform work efficiently and successfully.
#
# For the `Pokemon.csv` data set, fortunately, the owner provided descriptions which you can see [here](https://www.kaggle.com/abcsds/pokemon/home). For your convenience, we are including the descriptions below. Read the descriptions and understand what each column means. This knowledge is helpful in your work with the data.
#
# | Column | Description |
# | --- | --- |
# | # | ID for each pokemon |
# | Name | Name of each pokemon |
# | Type 1 | Each pokemon has a type, this determines weakness/resistance to attacks |
# | Type 2 | Some pokemon are dual type and have 2 |
# | Total | A general guide to how strong a pokemon is |
# | HP | Hit points, or health, defines how much damage a pokemon can withstand before fainting |
# | Attack | The base modifier for normal attacks (eg. Scratch, Punch) |
# | Defense | The base damage resistance against normal attacks |
# | SP Atk | Special attack, the base modifier for special attacks (e.g. fire blast, bubble beam) |
# | SP Def | The base damage resistance against special attacks |
# | Speed | Determines which pokemon attacks first each round |
# | Generation | Number of generation |
# | Legendary | True if Legendary Pokemon False if not |

# %% [markdown]
# #### Obtain the distinct values across `Type 1` and `Type 2`.
#
# Exctract all the values in `Type 1` and `Type 2`. Then create an array containing the distinct values across both fields.

# %%
print(pokemon['Type 1'].unique())

print(pokemon['Type 2'].unique())

# pokemon_types = pokemon[['Type 1','Type 2']]

# Pokemon['unique type'] = pd.unique(pokemon_types)

# print(Pokemon['unique type'])

# np.unique(pokemon[['Type 1', 'Type 2']].values)

list(pokemon['Type 1']+'-'+ pokemon['Type 2'])
# Out:
# ['Grass' 'Fire' 'Water' 'Bug' 'Normal' 'Poison' 'Electric' 'Ground'
#  'Fairy' 'Fighting' 'Psychic' 'Rock' 'Ghost' 'Ice' 'Dragon' 'Dark' 'Steel'
#  'Flying']
# ['Poison' nan 'Flying' 'Dragon' 'Ground' 'Fairy' 'Grass' 'Fighting'
#  'Psychic' 'Steel' 'Ice' 'Rock' 'Dark' 'Water' 'Electric' 'Fire' 'Ghost'
#  'Bug' 'Normal']
# ['Grass-Poison',
#  'Grass-Poison',
#  'Grass-Poison',
#  'Grass-Poison',
#  nan,
#  nan,
#  'Fire-Flying',
#  'Fire-Dragon',
#  'Fire-Flying',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'Bug-Flying',
#  'Bug-Poison',
#  'Bug-Poison',
#  'Bug-Poison',
#  'Bug-Poison',
#  'Normal-Flying',
#  'Normal-Flying',
#  'Normal-Flying',
#  'Normal-Flying',
#  nan,
#  nan,
#  'Normal-Flying',
#  'Normal-Flying',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'Poison-Ground',
#  nan,
#  nan,
#  'Poison-Ground',
#  nan,
#  nan,
#  nan,
#  nan,
#  'Normal-Fairy',
#  'Normal-Fairy',
#  'Poison-Flying',
#  'Poison-Flying',
#  'Grass-Poison',
#  'Grass-Poison',
#  'Grass-Poison',
#  'Bug-Grass',
#  'Bug-Grass',
#  'Bug-Poison',
#  'Bug-Poison',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'Water-Fighting',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'Grass-Poison',
#  'Grass-Poison',
#  'Grass-Poison',
#  'Water-Poison',
#  'Water-Poison',
#  'Rock-Ground',
#  'Rock-Ground',
#  'Rock-Ground',
#  nan,
#  nan,
#  'Water-Psychic',
#  'Water-Psychic',
#  'Water-Psychic',
#  'Electric-Steel',
#  'Electric-Steel',
#  'Normal-Flying',
#  'Normal-Flying',
#  'Normal-Flying',
#  nan,
#  'Water-Ice',
#  nan,
#  nan,
#  nan,
#  'Water-Ice',
#  'Ghost-Poison',
#  'Ghost-Poison',
#  'Ghost-Poison',
#  'Ghost-Poison',
#  'Rock-Ground',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'Grass-Psychic',
#  'Grass-Psychic',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'Ground-Rock',
#  'Ground-Rock',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'Water-Psychic',
#  'Psychic-Fairy',
#  'Bug-Flying',
#  'Ice-Psychic',
#  nan,
#  nan,
#  nan,
#  'Bug-Flying',
#  nan,
#  nan,
#  'Water-Flying',
#  'Water-Dark',
#  'Water-Ice',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'Rock-Water',
#  'Rock-Water',
#  'Rock-Water',
#  'Rock-Water',
#  'Rock-Flying',
#  'Rock-Flying',
#  nan,
#  'Ice-Flying',
#  'Electric-Flying',
#  'Fire-Flying',
#  nan,
#  nan,
#  'Dragon-Flying',
#  nan,
#  'Psychic-Fighting',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'Normal-Flying',
#  'Normal-Flying',
#  'Bug-Flying',
#  'Bug-Flying',
#  'Bug-Poison',
#  'Bug-Poison',
#  'Poison-Flying',
#  'Water-Electric',
#  'Water-Electric',
#  nan,
#  nan,
#  'Normal-Fairy',
#  nan,
#  'Fairy-Flying',
#  'Psychic-Flying',
#  'Psychic-Flying',
#  nan,
#  nan,
#  nan,
#  'Electric-Dragon',
#  nan,
#  'Water-Fairy',
#  'Water-Fairy',
#  nan,
#  nan,
#  'Grass-Flying',
#  'Grass-Flying',
#  'Grass-Flying',
#  nan,
#  nan,
#  nan,
#  'Bug-Flying',
#  'Water-Ground',
#  'Water-Ground',
#  nan,
#  nan,
#  'Dark-Flying',
#  'Water-Psychic',
#  nan,
#  nan,
#  nan,
#  'Normal-Psychic',
#  nan,
#  'Bug-Steel',
#  nan,
#  'Ground-Flying',
#  'Steel-Ground',
#  'Steel-Ground',
#  nan,
#  nan,
#  'Water-Poison',
#  'Bug-Steel',
#  'Bug-Steel',
#  'Bug-Rock',
#  'Bug-Fighting',
#  'Bug-Fighting',
#  'Dark-Ice',
#  nan,
#  nan,
#  nan,
#  'Fire-Rock',
#  'Ice-Ground',
#  'Ice-Ground',
#  'Water-Rock',
#  nan,
#  nan,
#  'Ice-Flying',
#  'Water-Flying',
#  'Steel-Flying',
#  'Dark-Fire',
#  'Dark-Fire',
#  'Dark-Fire',
#  'Water-Dragon',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'Ice-Psychic',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'Rock-Ground',
#  'Rock-Ground',
#  'Rock-Dark',
#  'Rock-Dark',
#  'Psychic-Flying',
#  'Fire-Flying',
#  'Psychic-Grass',
#  nan,
#  nan,
#  nan,
#  'Grass-Dragon',
#  nan,
#  'Fire-Fighting',
#  'Fire-Fighting',
#  'Fire-Fighting',
#  nan,
#  'Water-Ground',
#  'Water-Ground',
#  'Water-Ground',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'Bug-Flying',
#  nan,
#  'Bug-Poison',
#  'Water-Grass',
#  'Water-Grass',
#  'Water-Grass',
#  nan,
#  'Grass-Dark',
#  'Grass-Dark',
#  'Normal-Flying',
#  'Normal-Flying',
#  'Water-Flying',
#  'Water-Flying',
#  'Psychic-Fairy',
#  'Psychic-Fairy',
#  'Psychic-Fairy',
#  'Psychic-Fairy',
#  'Bug-Water',
#  'Bug-Flying',
#  nan,
#  'Grass-Fighting',
#  nan,
#  nan,
#  nan,
#  'Bug-Ground',
#  'Bug-Flying',
#  'Bug-Ghost',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'Normal-Fairy',
#  nan,
#  nan,
#  nan,
#  'Dark-Ghost',
#  'Dark-Ghost',
#  'Steel-Fairy',
#  'Steel-Fairy',
#  'Steel-Rock',
#  'Steel-Rock',
#  'Steel-Rock',
#  nan,
#  'Fighting-Psychic',
#  'Fighting-Psychic',
#  'Fighting-Psychic',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'Grass-Poison',
#  nan,
#  nan,
#  'Water-Dark',
#  'Water-Dark',
#  'Water-Dark',
#  nan,
#  nan,
#  'Fire-Ground',
#  'Fire-Ground',
#  'Fire-Ground',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'Ground-Dragon',
#  'Ground-Dragon',
#  nan,
#  'Grass-Dark',
#  'Normal-Flying',
#  'Dragon-Flying',
#  'Dragon-Fairy',
#  nan,
#  nan,
#  'Rock-Psychic',
#  'Rock-Psychic',
#  'Water-Ground',
#  'Water-Ground',
#  nan,
#  'Water-Dark',
#  'Ground-Psychic',
#  'Ground-Psychic',
#  'Rock-Grass',
#  'Rock-Grass',
#  'Rock-Bug',
#  'Rock-Bug',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'Grass-Flying',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'Ice-Water',
#  'Ice-Water',
#  'Ice-Water',
#  nan,
#  nan,
#  nan,
#  'Water-Rock',
#  nan,
#  nan,
#  nan,
#  'Dragon-Flying',
#  'Dragon-Flying',
#  'Steel-Psychic',
#  'Steel-Psychic',
#  'Steel-Psychic',
#  'Steel-Psychic',
#  nan,
#  nan,
#  nan,
#  'Dragon-Psychic',
#  'Dragon-Psychic',
#  'Dragon-Psychic',
#  'Dragon-Psychic',
#  nan,
#  nan,
#  nan,
#  'Ground-Fire',
#  'Dragon-Flying',
#  'Dragon-Flying',
#  'Steel-Psychic',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'Grass-Ground',
#  nan,
#  'Fire-Fighting',
#  'Fire-Fighting',
#  nan,
#  nan,
#  'Water-Steel',
#  'Normal-Flying',
#  'Normal-Flying',
#  'Normal-Flying',
#  nan,
#  'Normal-Water',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'Grass-Poison',
#  'Grass-Poison',
#  nan,
#  nan,
#  'Rock-Steel',
#  'Rock-Steel',
#  nan,
#  'Bug-Grass',
#  'Bug-Ground',
#  'Bug-Steel',
#  'Bug-Flying',
#  'Bug-Flying',
#  'Bug-Flying',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'Water-Ground',
#  nan,
#  'Ghost-Flying',
#  'Ghost-Flying',
#  nan,
#  nan,
#  'Normal-Fighting',
#  nan,
#  'Dark-Flying',
#  nan,
#  nan,
#  nan,
#  'Poison-Dark',
#  'Poison-Dark',
#  'Steel-Psychic',
#  'Steel-Psychic',
#  nan,
#  'Psychic-Fairy',
#  nan,
#  'Normal-Flying',
#  'Ghost-Dark',
#  'Dragon-Ground',
#  'Dragon-Ground',
#  'Dragon-Ground',
#  'Dragon-Ground',
#  nan,
#  nan,
#  'Fighting-Steel',
#  'Fighting-Steel',
#  nan,
#  nan,
#  'Poison-Bug',
#  'Poison-Dark',
#  'Poison-Fighting',
#  'Poison-Fighting',
#  nan,
#  nan,
#  nan,
#  'Water-Flying',
#  'Grass-Ice',
#  'Grass-Ice',
#  'Grass-Ice',
#  'Dark-Ice',
#  'Electric-Steel',
#  nan,
#  'Ground-Rock',
#  nan,
#  nan,
#  nan,
#  'Fairy-Flying',
#  'Bug-Flying',
#  nan,
#  nan,
#  'Ground-Flying',
#  'Ice-Ground',
#  nan,
#  'Psychic-Fighting',
#  'Psychic-Fighting',
#  'Rock-Steel',
#  nan,
#  'Ice-Ghost',
#  'Electric-Ghost',
#  'Electric-Fire',
#  'Electric-Water',
#  'Electric-Ice',
#  'Electric-Flying',
#  'Electric-Grass',
#  nan,
#  nan,
#  nan,
#  'Steel-Dragon',
#  'Water-Dragon',
#  'Fire-Steel',
#  nan,
#  'Ghost-Dragon',
#  'Ghost-Dragon',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'Grass-Flying',
#  nan,
#  'Psychic-Fire',
#  nan,
#  nan,
#  nan,
#  nan,
#  'Fire-Fighting',
#  'Fire-Fighting',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'Normal-Flying',
#  'Normal-Flying',
#  'Normal-Flying',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'Psychic-Flying',
#  'Psychic-Flying',
#  nan,
#  'Ground-Steel',
#  nan,
#  'Normal-Fairy',
#  nan,
#  nan,
#  nan,
#  nan,
#  'Water-Ground',
#  'Water-Ground',
#  nan,
#  nan,
#  'Bug-Grass',
#  'Bug-Grass',
#  'Bug-Grass',
#  'Bug-Poison',
#  'Bug-Poison',
#  'Bug-Poison',
#  'Grass-Fairy',
#  'Grass-Fairy',
#  nan,
#  nan,
#  nan,
#  'Ground-Dark',
#  'Ground-Dark',
#  'Ground-Dark',
#  nan,
#  nan,
#  'Fire-Psychic',
#  nan,
#  'Bug-Rock',
#  'Bug-Rock',
#  'Dark-Fighting',
#  'Dark-Fighting',
#  'Psychic-Flying',
#  nan,
#  nan,
#  'Water-Rock',
#  'Water-Rock',
#  'Rock-Flying',
#  'Rock-Flying',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'Water-Flying',
#  'Water-Flying',
#  nan,
#  nan,
#  nan,
#  'Normal-Grass',
#  'Normal-Grass',
#  'Electric-Flying',
#  nan,
#  'Bug-Steel',
#  'Grass-Poison',
#  'Grass-Poison',
#  'Water-Ghost',
#  'Water-Ghost',
#  nan,
#  'Bug-Electric',
#  'Bug-Electric',
#  'Grass-Steel',
#  'Grass-Steel',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'Ghost-Fire',
#  'Ghost-Fire',
#  'Ghost-Fire',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'Ground-Electric',
#  nan,
#  nan,
#  nan,
#  'Ground-Ghost',
#  'Ground-Ghost',
#  'Dark-Steel',
#  'Dark-Steel',
#  nan,
#  'Normal-Flying',
#  'Normal-Flying',
#  'Dark-Flying',
#  'Dark-Flying',
#  nan,
#  'Bug-Steel',
#  'Dark-Dragon',
#  'Dark-Dragon',
#  'Dark-Dragon',
#  'Bug-Fire',
#  'Bug-Fire',
#  'Steel-Fighting',
#  'Rock-Fighting',
#  'Grass-Fighting',
#  nan,
#  nan,
#  'Electric-Flying',
#  'Electric-Flying',
#  'Dragon-Fire',
#  'Dragon-Electric',
#  'Ground-Flying',
#  'Ground-Flying',
#  'Dragon-Ice',
#  'Dragon-Ice',
#  'Dragon-Ice',
#  'Water-Fighting',
#  'Water-Fighting',
#  'Normal-Psychic',
#  'Normal-Fighting',
#  'Bug-Steel',
#  nan,
#  nan,
#  'Grass-Fighting',
#  nan,
#  nan,
#  'Fire-Psychic',
#  nan,
#  nan,
#  'Water-Dark',
#  nan,
#  'Normal-Ground',
#  'Normal-Flying',
#  'Fire-Flying',
#  'Fire-Flying',
#  nan,
#  nan,
#  'Bug-Flying',
#  'Fire-Normal',
#  'Fire-Normal',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'Fighting-Dark',
#  nan,
#  nan,
#  nan,
#  nan,
#  'Steel-Ghost',
#  'Steel-Ghost',
#  'Steel-Ghost',
#  'Steel-Ghost',
#  nan,
#  nan,
#  nan,
#  nan,
#  'Dark-Psychic',
#  'Dark-Psychic',
#  'Rock-Water',
#  'Rock-Water',
#  'Poison-Water',
#  'Poison-Dragon',
#  nan,
#  nan,
#  'Electric-Normal',
#  'Electric-Normal',
#  'Rock-Dragon',
#  'Rock-Dragon',
#  'Rock-Ice',
#  'Rock-Ice',
#  nan,
#  'Fighting-Flying',
#  'Electric-Fairy',
#  'Rock-Fairy',
#  nan,
#  nan,
#  nan,
#  'Steel-Fairy',
#  'Ghost-Grass',
#  'Ghost-Grass',
#  'Ghost-Grass',
#  'Ghost-Grass',
#  'Ghost-Grass',
#  'Ghost-Grass',
#  'Ghost-Grass',
#  'Ghost-Grass',
#  'Ghost-Grass',
#  'Ghost-Grass',
#  nan,
#  nan,
#  'Flying-Dragon',
#  'Flying-Dragon',
#  nan,
#  'Dark-Flying',
#  'Dragon-Ground',
#  'Rock-Fairy',
#  'Rock-Fairy',
#  'Psychic-Ghost',
#  'Psychic-Dark',
#  'Fire-Water']

# %%
pokemon_types.head()
# Out:
#   Type 1  Type 2
# 0  Grass  Poison
# 1  Grass  Poison
# 2  Grass  Poison
# 3  Grass  Poison
# 4   Fire     NaN

# %% [markdown]
# #### Cleanup `Name` that contain "Mega".
#
# If you have checked out the pokemon names carefully enough, you should have found there are junk texts in the pokemon names which contain "Mega". We want to clean up the pokemon names. For instance, "VenusaurMega Venusaur" should be "Mega Venusaur", and "CharizardMega Charizard X" should be "Mega Charizard X".

# %%
# test transformed data
pokemon.head(10)
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                    Ivysaur  Grass  Poison    405  60      62       63
# 2  3                   Venusaur  Grass  Poison    525  80      82       83
# 3  3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4                 Charmander   Fire     NaN    309  39      52       43
# 5  5                 Charmeleon   Fire     NaN    405  58      64       58
# 6  6                  Charizard   Fire  Flying    534  78      84       78
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8  6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9  7                   Squirtle  Water     NaN    314  44      48       65
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary    all_types  A/D Ratio
# 0       65       65     45           1      False  GrassPoison   1.000000
# 1       80       80     60           1      False  GrassPoison   0.984127
# 2      100      100     80           1      False  GrassPoison   0.987952
# 3      122      120     80           1      False  GrassPoison   0.813008
# 4       60       50     65           1      False          NaN   1.209302
# 5       80       65     80           1      False          NaN   1.103448
# 6      109       85    100           1      False   FireFlying   1.076923
# 7      130       85    100           1      False   FireDragon   1.171171
# 8      159      115    100           1      False   FireFlying   1.333333
# 9       50       64     43           1      False          NaN   0.738462

# %% [markdown]
# #### Create a new column called `A/D Ratio` whose value equals to `Attack` devided by `Defense`.
#
# For instance, if a pokemon has the Attack score 49 and Defense score 49, the corresponding `A/D Ratio` is 49/49=1.

# %%
pokemon['A/D Ratio'] = pokemon['Attack']/pokemon['Defense']

pokemon.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary    all_types  A/D Ratio
# 0       65       65     45           1      False  GrassPoison   1.000000
# 1       80       80     60           1      False  GrassPoison   0.984127
# 2      100      100     80           1      False  GrassPoison   0.987952
# 3      122      120     80           1      False  GrassPoison   0.813008
# 4       60       50     65           1      False          NaN   1.209302

# %% [markdown]
# #### Identify the pokemon with the highest `A/D Ratio`.

# %%
pokemon[pokemon['A/D Ratio']== pokemon['A/D Ratio'].max()]
# Out:
#        #                Name   Type 1 Type 2  Total  HP  Attack  Defense  \
# 429  386  DeoxysAttack Forme  Psychic    NaN    600  50     180       20
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary all_types  A/D Ratio
# 429      180       20    150           3       True       NaN        9.0

# %% [markdown]
# #### Identify the pokemon with the lowest A/D Ratio.

# %%
pokemon[pokemon['A/D Ratio']== pokemon['A/D Ratio'].min()]# your code here
# Out:
#        #     Name Type 1 Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 230  213  Shuckle    Bug   Rock    505  20      10      230       10      230
#
#      Speed  Generation  Legendary all_types  A/D Ratio
# 230      5           2      False   BugRock   0.043478

# %% [markdown]
# #### Create a new column called `Combo Type` whose value combines `Type 1` and `Type 2`.
#
# Rules:
#
# * If both `Type 1` and `Type 2` have valid values, the `Combo Type` value should contain both values in the form of `<Type 1> <Type 2>`. For example, if `Type 1` value is `Grass` and `Type 2` value is `Poison`, `Combo Type` will be `Grass-Poison`.
#
# * If `Type 1` has valid value but `Type 2` is not, `Combo Type` will be the same as `Type 1`. For example, if `Type 1` is `Fire` whereas `Type 2` is `NaN`, `Combo Type` will be `Fire`.

# %%
# pokemon['Combo Type'] = list(pokemon['Type 1'].astype(str).fillna('')+'-'+ pokemon['Type 2'].astype(str).fillna(''))

combo_type_def(combo_type)

def combo_type_def(row):
    type_1 = pokemon['Type 1']
    type_2 = pokemon['Type 2']

    if type_2 != string:
        return type_1    
    else:
        return type_1+'-'+type_2
    
list(map(combo_type_def,pokemon['combo_type']))

pokemon.head(20)
# Out:
#      #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0    1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1    2                    Ivysaur  Grass  Poison    405  60      62       63
# 2    3                   Venusaur  Grass  Poison    525  80      82       83
# 3    3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4    4                 Charmander   Fire     NaN    309  39      52       43
# 5    5                 Charmeleon   Fire     NaN    405  58      64       58
# 6    6                  Charizard   Fire  Flying    534  78      84       78
# 7    6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8    6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9    7                   Squirtle  Water     NaN    314  44      48       65
# 10   8                  Wartortle  Water     NaN    405  59      63       80
# 11   9                  Blastoise  Water     NaN    530  79      83      100
# 12   9    BlastoiseMega Blastoise  Water     NaN    630  79     103      120
# 13  10                   Caterpie    Bug     NaN    195  45      30       35
# 14  11                    Metapod    Bug     NaN    205  50      20       55
# 15  12                 Butterfree    Bug  Flying    395  60      45       50
# 16  13                     Weedle    Bug  Poison    195  40      35       30
# 17  14                     Kakuna    Bug  Poison    205  45      25       50
# 18  15                   Beedrill    Bug  Poison    395  65      90       40
# 19  15      BeedrillMega Beedrill    Bug  Poison    495  65     150       40
#
#     Sp. Atk  Sp. Def  Speed  Generation  Legendary    all_types  A/D Ratio  \
# 0        65       65     45           1      False  GrassPoison   1.000000
# 1        80       80     60           1      False  GrassPoison   0.984127
# 2       100      100     80           1      False  GrassPoison   0.987952
# 3       122      120     80           1      False  GrassPoison   0.813008
# 4        60       50     65           1      False          NaN   1.209302
# 5        80       65     80           1      False          NaN   1.103448
# 6       109       85    100           1      False   FireFlying   1.076923
# 7       130       85    100           1      False   FireDragon   1.171171
# 8       159      115    100           1      False   FireFlying   1.333333
# 9        50       64     43           1      False          NaN   0.738462
# 10       65       80     58           1      False          NaN   0.787500
# 11       85      105     78           1      False          NaN   0.830000
# 12      135      115     78           1      False          NaN   0.858333
# 13       20       20     45           1      False          NaN   0.857143
# 14       25       25     30           1      False          NaN   0.363636
# 15       90       80     70           1      False    BugFlying   0.900000
# 16       20       20     50           1      False    BugPoison   1.166667
# 17       25       25     35           1      False    BugPoison   0.500000
# 18       45       80     75           1      False    BugPoison   2.250000
# 19       15       80    145           1      False    BugPoison   3.750000
#
#       Combo Type
# 0   Grass-Poison
# 1   Grass-Poison
# 2   Grass-Poison
# 3   Grass-Poison
# 4       Fire-nan
# 5       Fire-nan
# 6    Fire-Flying
# 7    Fire-Dragon
# 8    Fire-Flying
# 9      Water-nan
# 10     Water-nan
# 11     Water-nan
# 12     Water-nan
# 13       Bug-nan
# 14       Bug-nan
# 15    Bug-Flying
# 16    Bug-Poison
# 17    Bug-Poison
# 18    Bug-Poison
# 19    Bug-Poison

# %% [markdown]
# #### Identify the pokemon whose `A/D Ratio` are among the top 5.

# %%
pokemon['A/D Ratio'].nlargest(n=5)
# Out:
# 429    9.000
# 347    4.500
# 19     3.750
# 453    3.125
# 348    3.000
# Name: A/D Ratio, dtype: float64

# %% [markdown]
# #### For the 5 pokemon printed above, aggregate `Combo Type` and use a list to store the unique values.
#
# Your end product is a list containing the distinct `Combo Type` values of the 5 pokemon with the highest `A/D Ratio`.

# %%
# your code here

# %% [markdown]
# #### For each of the `Combo Type` values obtained from the previous question, calculate the mean scores of all numeric fields across all pokemon.
#
# Your output should look like below:
#
# ![Aggregate](../images/aggregated-mean.png)

# %%
# your code here
